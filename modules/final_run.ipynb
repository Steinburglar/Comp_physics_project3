# %% [markdown]
# Final Jupyter notebook to run code for Project 3 Ising model
# Lucas Steinberger,
# 04/05/2024

# %%
import lattice
import metroplois2
import graph
import SW_Class
from IPython.display import Video

# %% [markdown]
# Start with a metropolis algorthm for a 10x10 square lattice:
# We will run the metrolpolis algorithm at a variety of temperatures, and plot the equilibrium magnetism as a function of the temperature
#
# we will also display a vizualization animation of the algorithm running

# %%
T = 1 #arbitrarily initialize T
square_lattice = lattice.Lattice(J = 1)
Squr_alg = metroplois2.Metroplois(square_lattice, T)
Squr_alg.plot_mag_temp(5000, 21, 'Metropolis_anim.mp4')
Video('Metropolis_anim.mp4')
# Out:
# ......
# <video src="Metropolis_anim.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Next, we will do the same for a similar program for the SW algorithm, which uses a clustering approach similar to the wolff algorithm.

# %%
square_df = square_lattice.get_lattice()
square_sw_alg = SW_Class.SW_algorithm(square_df, 10, 2)
square_sw_alg.plot_mag_temp(5000, 21, 'SW_anim.mp4')
# Out:
# ...........

# %%
Video('SW_anim.mp4')
# Out:
# <video src="SW_anim.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Next, we will try both again but this time with "holes" in our Ising model, whoch are lattice sites with no atom within them. the goal is to see if the magnetization trends change with such holes, and if so, in what ways does it change.

# %%
T = 1 #arbitrarily initialize T
square_lattice_holes = lattice.Lattice(J = 1, holes=0.25)
Squr_alg = metroplois2.Metroplois(square_lattice_holes, T)
Squr_alg.plot_mag_temp(10000, 21, 'Metropolis_holes_anim.mp4')
Video('Metropolis_holes_anim.mp4')
# Out:
# ......
# <video src="Metropolis_holes_anim.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
square_df_holes = square_lattice_holes.get_lattice()
square_sw_alg_holes = SW_Class.SW_algorithm(square_df, 10, 2)
square_sw_alg_holes.plot_mag_temp(10000, 21, 'SW_holes_anim.mp4')
Video('SW_holes_anim.mp4')
# Out:
# ...........
# <video src="SW_holes_anim.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
T = 1 #arbitrarily initialize T
big_lattice = lattice.Lattice(size= 100, J = 1)
big_alg = metroplois2.Metroplois(big_lattice, T)
big_alg.plot_mag_temp(10000, 21, 'Metropolis_big_anim.mp4')
Video('Metropolis_big_anim.mp4')
# Out:
# ......
# <video src="Metropolis_big_anim.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
